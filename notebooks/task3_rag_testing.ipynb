# %%
import sys
import os

project_root = os.path.abspath("..")
if project_root not in sys.path:
    sys.path.append(project_root)

# %%
import pandas as pd
import pyarrow.parquet as pq

# Load parquet via pyarrow
table = pq.read_table("../data/processed/complaint_embeddings.parquet")

# Convert to pandas dataframe, coerce types
df = table.to_pandas(strings_to_categorical=False)
print(df.columns)
print(df.head())
# Out:
# Running cells with 'Python 3.14.0' requires the ipykernel package.
#
# Install 'ipykernel' into the Python environment.
#
# Command: 'c:/Python314/python.exe -m pip install ipykernel -U --user --force-reinstall'

# %%
import chromadb
from chromadb.config import Settings

client = chromadb.Client(
    Settings(persist_directory="vector_store")
)

print(client.list_collections())
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[6], line 4
#       1 import chromadb
#       2 from chromadb.config import Settings
# ----> 4 client = chromadb.Client(
#       5     Settings(persist_directory="vector_store")
#       6 )
#       8 print(client.list_collections())
#
# File c:\Users\Hanan\Downloads\Week-7 Project\Intelligent-Complaint-Analysis-for-Financial-Services-Week-7-Project-\venv311\Lib\site-packages\chromadb\__init__.py:432, in Client(settings, tenant, database)
#     429 tenant = str(tenant)
#     430 database = str(database)
# --> 432 return ClientCreator(tenant=tenant, database=database, settings=settings)
#
# File c:\Users\Hanan\Downloads\Week-7 Project\Intelligent-Complaint-Analysis-for-Financial-Services-Week-7-Project-\venv311\Lib\site-packages\chromadb\api\client.py:66, in Client.__init__(self, tenant, database, settings)
# ...

# %%
from src.pipeline import RAGPipeline

rag = RAGPipeline()

rag.ask("Why are customers unhappy with credit cards?")
# Out:
# ---------------------------------------------------------------------------
# NotFoundError                             Traceback (most recent call last)
# Cell In[5], line 3
#       1 from src.pipeline import RAGPipeline
# ----> 3 rag = RAGPipeline()
#       5 rag.ask("Why are customers unhappy with credit cards?")
#
# File c:\Users\Hanan\Downloads\Week-7 Project\Intelligent-Complaint-Analysis-for-Financial-Services-Week-7-Project-\src\pipeline.py:8, in RAGPipeline.__init__(self)
#       7 def __init__(self):
# ----> 8     self.retriever = ComplaintRetriever()
#       9     self.generator = AnswerGenerator()
#
# File c:\Users\Hanan\Downloads\Week-7 Project\Intelligent-Complaint-Analysis-for-Financial-Services-Week-7-Project-\src\rag\retriever.py:14, in ComplaintRetriever.__init__(self, persist_dir)
#       8 self.embedding_model = SentenceTransformer("all-MiniLM-L6-v2")
#      10 self.client = chromadb.Client(
#      11     Settings(persist_directory=persist_dir)
#      12 )
# ...
